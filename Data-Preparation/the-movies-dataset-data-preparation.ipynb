# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/the-movies-dataset/ratings.csv
# /kaggle/input/the-movies-dataset/links_small.csv
# /kaggle/input/the-movies-dataset/credits.csv
# /kaggle/input/the-movies-dataset/keywords.csv
# /kaggle/input/the-movies-dataset/movies_metadata.csv
# /kaggle/input/the-movies-dataset/ratings_small.csv
# /kaggle/input/the-movies-dataset/links.csv
# /kaggle/input/spoken-lang/spoken_lang.csv

# %% [markdown]
# # Load Data

# %%
import glob
# load all csv files
file_dir  = '/kaggle/input/the-movies-dataset'
files =  glob.glob(os.path.join(file_dir, "*.csv"))

# %%
df_dict = dict()
for file in files:
    df_dict[os.path.splitext(os.path.basename(file))[0]] = pd.read_csv(file, low_memory=False)

# %%
df_dict.keys()
# Out:
# dict_keys(['ratings', 'links_small', 'credits', 'keywords', 'movies_metadata', 'ratings_small', 'links'])

# %%
# for df_name,df_ in df_dict.items():
#     print(f"----------------- {df_name} -----------------")
#     print(df_.sample(3),end='\n\n')

# %% [markdown]
# # Data Preparation

# %%
df_dict['credits'].sample(5)
# Out:
#                                                     cast  \
# 38657  [{'cast_id': 1, 'character': '', 'credit_id': ...
# 20011  [{'cast_id': 2, 'character': 'Syd March', 'cre...
# 45153  [{'cast_id': 4, 'character': 'Olga', 'credit_i...
# 7701   [{'cast_id': 4, 'character': 'Robert Rainsford...
# 14409                                                 []
#
#                                                     crew      id
# 38657  [{'credit_id': '54be140e9251411d7700c944', 'de...  319632
# 20011  [{'credit_id': '52fe4ac7c3a368484e16672b', 'de...  125490
# 45153  [{'credit_id': '53c7fa6ec3a368624b003d54', 'de...   61266
# 7701   [{'credit_id': '52fe432ac3a36847f803f2d9', 'de...    1994
# 14409                                                 []   52048

# %% [markdown]
# ## helper Functions

# %%
import json
import ast
def filter_str(st:str)->list:
    list_ = []
    i = 0
    if st == 0:
        return []
    if isinstance(st,str):
        while i < len(st):
            if st[i] == '[' or st[i] == ']':
                i += 1
                continue
            temp = ''
            if st[i] == '{':
                while st[i] != '}':
                    temp += st[i]
                    i+=1
            if temp != '':      
                temp += '}'
                list_.append(ast.literal_eval(temp)) 
            i += 1
    return list_   

def get_dataframe(df:pd.Series, col:str, ids_relation:pd.Series)->pd.DataFrame:
    arr = []
    counter = 0
    for st in list(df):
        if st:
            lst = filter_str(st)
            for item in lst:
                arr.append(list(item.values())+[ids_relation[counter]])
#             arr.extend([int(ids_relation[counter])]*len(lst))
            counter +=1
        else:
#             arr.append([np.nan]*)
            pass
            
    if col == 'cast':        
        return pd.DataFrame(arr,columns= ['cast_id','character','credit_id','gender','id','name','order','profile_path','id_relation'])
    elif col == 'crew':
        return pd.DataFrame(arr,columns=['credit_id','department','gender','id','job','name','profile_path','id_relation'])
    elif col == 'keywords':
        return pd.DataFrame(arr,columns=['id','name','id_relation'])

# %% [markdown]
# ## Prepare Credits Table

# %%
cast_df = get_dataframe(df_dict['credits'].cast,col='cast',ids_relation = df_dict['credits']['id'])

# %%
cast_df.head()
# Out:
#    cast_id                character                 credit_id  gender     id  \
# 0       14            Woody (voice)  52fe4284c3a36847f8024f95       2     31
# 1       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2  12898
# 2       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2   7167
# 3       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2  12899
# 4       18              Rex (voice)  52fe4284c3a36847f8024fa5       2  12900
#
#             name  order                      profile_path  id_relation
# 0      Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg          862
# 1      Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg          862
# 2    Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg          862
# 3     Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg          862
# 4  Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg          862

# %%
crew_df = get_dataframe(df_dict['credits'].crew,col='crew',ids_relation = df_dict['credits']['id'])

# %%
crew_df.head()
# Out:
#                   credit_id department  gender     id         job  \
# 0  52fe4284c3a36847f8024f49  Directing       2   7879    Director
# 1  52fe4284c3a36847f8024f4f    Writing       2  12891  Screenplay
# 2  52fe4284c3a36847f8024f55    Writing       2      7  Screenplay
# 3  52fe4284c3a36847f8024f5b    Writing       2  12892  Screenplay
# 4  52fe4284c3a36847f8024f61    Writing       0  12893  Screenplay
#
#              name                      profile_path  id_relation
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg          862
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg          862
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg          862
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg          862
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg          862

# %%
cast_df.head()
# Out:
#    cast_id                character                 credit_id  gender     id  \
# 0       14            Woody (voice)  52fe4284c3a36847f8024f95       2     31
# 1       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2  12898
# 2       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2   7167
# 3       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2  12899
# 4       18              Rex (voice)  52fe4284c3a36847f8024fa5       2  12900
#
#             name  order                      profile_path  id_relation
# 0      Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg          862
# 1      Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg          862
# 2    Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg          862
# 3     Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg          862
# 4  Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg          862

# %%
del df_dict['credits']

# %%
df_dict['cast'] = cast_df
df_dict['crew'] = crew_df

# %% [markdown]
# ## Prepare Keywords Table

# %%
df_dict['keywords']
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
keywords_df = get_dataframe(df = df_dict['keywords']['keywords'],
                            col='keywords',
                            ids_relation=df_dict['keywords']['id'])

# %%
keywords_df.head()
# Out:
#      id        name  id_relation
# 0   931    jealousy          862
# 1  4290         toy          862
# 2  5202         boy          862
# 3  6054  friendship          862
# 4  9713     friends          862

# %%
df_dict['keywords'] = keywords_df

# %%
df_dict['keywords']
# Out:
#             id          name  id_relation
# 0          931      jealousy          862
# 1         4290           toy          862
# 2         5202           boy          862
# 3         6054    friendship          862
# 4         9713       friends          862
# ...        ...           ...          ...
# 158675   11800  mockumentary       289923
# 158676   10703   tragic love       439050
# 158677    2679        artist       111109
# 158678   14531          play       111109
# 158679  215397         pinoy       111109
#
# [158680 rows x 3 columns]

# %%
df_dict.keys()
# Out:
# dict_keys(['ratings', 'links_small', 'keywords', 'movies_metadata', 'ratings_small', 'links', 'cast', 'crew'])

# %% [markdown]
# ## Prepare ratings Table

# %%
df_dict['ratings']['timestamp'] = pd.to_datetime((df_dict['ratings']['timestamp']),unit='s')

# %%
df_dict['ratings']
# Out:
#           userId  movieId  rating           timestamp
# 0              1      110     1.0 2015-03-09 22:52:09
# 1              1      147     4.5 2015-03-09 23:07:15
# 2              1      858     5.0 2015-03-09 22:52:03
# 3              1     1221     5.0 2015-03-09 22:52:26
# 4              1     1246     5.0 2015-03-09 22:52:36
# ...          ...      ...     ...                 ...
# 26024284  270896    58559     5.0 2009-10-31 23:26:04
# 26024285  270896    60069     5.0 2009-10-31 23:33:52
# 26024286  270896    63082     4.5 2009-10-31 23:29:24
# 26024287  270896    64957     4.5 2009-11-01 00:06:30
# 26024288  270896    71878     2.0 2009-10-31 23:30:58
#
# [26024289 rows x 4 columns]

# %%
df_dict['ratings_small']['timestamp'] = pd.to_datetime(df_dict['ratings_small']['timestamp'],unit='s')

# %%
df_dict['ratings_small']
# Out:
#         userId  movieId  rating           timestamp
# 0            1       31     2.5 2009-12-14 02:52:24
# 1            1     1029     3.0 2009-12-14 02:52:59
# 2            1     1061     3.0 2009-12-14 02:53:02
# 3            1     1129     2.0 2009-12-14 02:53:05
# 4            1     1172     4.0 2009-12-14 02:53:25
# ...        ...      ...     ...                 ...
# 99999      671     6268     2.5 2003-10-08 02:16:10
# 100000     671     6269     4.0 2003-10-03 02:46:41
# 100001     671     6365     4.0 2003-12-09 03:26:03
# 100002     671     6385     2.5 2003-12-09 14:21:03
# 100003     671     6565     3.5 2004-01-22 15:18:44
#
# [100004 rows x 4 columns]

# %% [markdown]
# ## Prepare movies mate date Table

# %%
pd.set_option('display.max_columns', None)
df_dict['movies_metadata']
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [45466 rows x 24 columns]

# %%
df_dict['movies_metadata'].columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
"""
belongs_to_collection,
genres,
production_companies,
production_countries,
spoken_languages
"""
# Out:
# '\nbelongs_to_collection,\ngenres,\nproduction_companies,\nproduction_countries,\nspoken_languages\n'

# %%
df_dict['movies_metadata']['belongs_to_collection'] = df_dict['movies_metadata']['belongs_to_collection'].apply(lambda x: filter_str(x)[0]['name'] if filter_str(x) else np.nan)

# %%
df_dict['movies_metadata'].isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40975
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
for item in df_dict['movies_metadata']['genres'][:10]:
    print(item)
# Out:
# [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# [{'id': 35, 'name': 'Comedy'}]
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 53, 'name': 'Thriller'}]
# [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]

# %% [markdown]
# *relation between movie and genre is meny-to-meny*
# > we can split the genre to seperate table and create the relation between genre and movie with separate table also

# %%
genre_dict = dict()
for genre in list(df_dict['movies_metadata']['genres']):
    lst = filter_str(genre)
#     print(lst)
    for item in lst:
        if int(item['id']) not in genre_dict:
            genre_dict[int(item['id'])] = item['name']

# %%
genre_dict = dict(sorted(genre_dict.items()))
genre_dict
# Out:
# {12: 'Adventure',
#  14: 'Fantasy',
#  16: 'Animation',
#  18: 'Drama',
#  27: 'Horror',
#  28: 'Action',
#  35: 'Comedy',
#  36: 'History',
#  37: 'Western',
#  53: 'Thriller',
#  80: 'Crime',
#  99: 'Documentary',
#  878: 'Science Fiction',
#  2883: 'Aniplex',
#  7759: 'GoHands',
#  7760: 'BROSTA TV',
#  7761: 'Mardock Scramble Production Committee',
#  9648: 'Mystery',
#  10402: 'Music',
#  10749: 'Romance',
#  10751: 'Family',
#  10752: 'War',
#  10769: 'Foreign',
#  10770: 'TV Movie',
#  11176: 'Carousel Productions',
#  11602: 'Vision View Entertainment',
#  17161: 'Odyssey Media',
#  18012: 'Pulser Productions',
#  18013: 'Rogue State',
#  23822: 'The Cartel',
#  29812: 'Telescene Film Group Productions',
#  33751: 'Sentai Filmworks'}

# %%
def handle_genre(genre):
    lst = filter_str(genre)
    ids = [item['id'] for item in lst if 'id' in item]
    return ids

# handle_genre(df_dict['movies_metadata']['genres'][2])
genre_relation  = df_dict['movies_metadata']['genres'].apply(lambda x: handle_genre(x))

# %%
df_dict['movies_metadata']['genres'] = genre_relation

# %%
temp = df_dict['movies_metadata'][['genres','id']]

# %%
df_temp = temp.explode('genres')
df_temp.rename(columns = {'genres':'genre_id','id':'movie_id'}, inplace = True)
df_temp.reset_index(drop=True)
# Out:
#       genre_id movie_id
# 0           16      862
# 1           35      862
# 2        10751      862
# 3           12     8844
# 4           14     8844
# ...        ...      ...
# 93543       28    67758
# 93544       18    67758
# 93545       53    67758
# 93546      NaN   227506
# 93547      NaN   461257
#
# [93548 rows x 2 columns]

# %%
df_temp.dropna(inplace=True)

# %%
df_dict['genre_movie_relation'] = df_temp

# %%
df_dict['genre_dict'] = genre_dict

# %%
df_dict['movies_metadata'].drop(['genres'],axis=1,inplace=True)
df_dict['movies_metadata']
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                             NaN  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                             NaN  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 45461  False                             NaN         0
# 45462  False                             NaN         0
# 45463  False                             NaN         0
# 45464  False                             NaN         0
# 45465  False                             NaN         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [45466 rows x 23 columns]

# %%
for country in df_dict['movies_metadata']['production_countries'][:20]:
    print(country)
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
countries = dict()
for genre in list(df_dict['movies_metadata']['production_countries']):
    lst = filter_str(genre)
    for item in lst:
        if (item['iso_3166_1']) not in countries:
            countries[item['iso_3166_1']] = item['name']

# %%
countries
# Out:
# {'US': 'United States of America',
#  'DE': 'Germany',
#  'GB': 'United Kingdom',
#  'FR': 'France',
#  'IT': 'Italy',
#  'ES': 'Spain',
#  'CN': 'China',
#  'AU': 'Australia',
#  'ZA': 'South Africa',
#  'CA': 'Canada',
#  'CH': 'Switzerland',
#  'BE': 'Belgium',
#  'JP': 'Japan',
#  'IR': 'Iran',
#  'NL': 'Netherlands',
#  'HK': 'Hong Kong',
#  'TN': 'Tunisia',
#  'IE': 'Ireland',
#  'DO': 'Dominican Republic',
#  'HR': 'Croatia',
#  'RU': 'Russia',
#  'MK': 'Macedonia',
#  'AT': 'Austria',
#  'TW': 'Taiwan',
#  'NZ': 'New Zealand',
#  'MX': 'Mexico',
#  'PL': 'Poland',
#  'PE': 'Peru',
#  'CU': 'Cuba',
#  'LI': 'Liechtenstein',
#  'DK': 'Denmark',
#  'PT': 'Portugal',
#  'FI': 'Finland',
#  'SE': 'Sweden',
#  'AR': 'Argentina',
#  'IS': 'Iceland',
#  'KR': 'South Korea',
#  'RS': 'Serbia',
#  'HU': 'Hungary',
#  'CZ': 'Czech Republic',
#  'IN': 'India',
#  'BR': 'Brazil',
#  'GR': 'Greece',
#  'CD': 'Congo',
#  'SN': 'Senegal',
#  'BF': 'Burkina Faso',
#  'RO': 'Romania',
#  'PH': 'Philippines',
#  'VN': 'Vietnam',
#  'TT': 'Trinidad and Tobago',
#  'BG': 'Bulgaria',
#  'CL': 'Chile',
#  'NO': 'Norway',
#  'KZ': 'Kazakhstan',
#  'DZ': 'Algeria',
#  'LU': 'Luxembourg',
#  'GE': 'Georgia',
#  'UA': 'Ukraine',
#  'BW': 'Botswana',
#  'AW': 'Aruba',
#  'IL': 'Israel',
#  'TR': 'Turkey',
#  'EC': 'Ecuador',
#  'LB': 'Lebanon',
#  'MA': 'Morocco',
#  'BA': 'Bosnia and Herzegovina',
#  'BS': 'Bahamas',
#  'MY': 'Malaysia',
#  'BT': 'Bhutan',
#  'JM': 'Jamaica',
#  'PK': 'Pakistan',
#  'NP': 'Nepal',
#  'CI': "Cote D'Ivoire",
#  'TH': 'Thailand',
#  'NA': 'Namibia',
#  'CM': 'Cameroon',
#  'CO': 'Colombia',
#  'XC': 'Czechoslovakia',
#  'UY': 'Uruguay',
#  'SI': 'Slovenia',
#  'LY': 'Libyan Arab Jamahiriya',
#  'PR': 'Puerto Rico',
#  'SU': 'Soviet Union',
#  'XG': 'East Germany',
#  'SG': 'Singapore',
#  'AF': 'Afghanistan',
#  'MT': 'Malta',
#  'PA': 'Panama',
#  'EG': 'Egypt',
#  'ZW': 'Zimbabwe',
#  'TJ': 'Tajikistan',
#  'UZ': 'Uzbekistan',
#  'CR': 'Costa Rica',
#  'KW': 'Kuwait',
#  'MQ': 'Martinique',
#  'GH': 'Ghana',
#  'AM': 'Armenia',
#  'ID': 'Indonesia',
#  'MN': 'Mongolia',
#  'BO': 'Bolivia',
#  'MC': 'Monaco',
#  'IQ': 'Iraq',
#  'SK': 'Slovakia',
#  'CS': 'Serbia and Montenegro',
#  'VE': 'Venezuela',
#  'LT': 'Lithuania',
#  'RW': 'Rwanda',
#  'PS': 'Palestinian Territory',
#  'TD': 'Chad',
#  'PY': 'Paraguay',
#  'QA': 'Qatar',
#  'EE': 'Estonia',
#  'MO': 'Macao',
#  'ML': 'Mali',
#  'UM': 'United States Minor Outlying Islands',
#  'LV': 'Latvia',
#  'AE': 'United Arab Emirates',
#  'AZ': 'Azerbaijan',
#  'KY': 'Cayman Islands',
#  'NI': 'Nicaragua',
#  'LR': 'Liberia',
#  'YU': 'Yugoslavia',
#  'ME': 'Montenegro',
#  'AO': 'Angola',
#  'BY': 'Belarus',
#  'KH': 'Cambodia',
#  'MR': 'Mauritania',
#  'CY': 'Cyprus',
#  'BD': 'Bangladesh',
#  'SY': 'Syrian Arab Republic',
#  'KG': 'Kyrgyz Republic',
#  'AL': 'Albania',
#  'TZ': 'Tanzania',
#  'KP': 'North Korea',
#  'KE': 'Kenya',
#  'JO': 'Jordan',
#  'UG': 'Uganda',
#  'SA': 'Saudi Arabia',
#  'SO': 'Somalia',
#  'GT': 'Guatemala',
#  'MG': 'Madagascar',
#  'ET': 'Ethiopia',
#  'LK': 'Sri Lanka',
#  'PG': 'Papua New Guinea',
#  'NG': 'Nigeria',
#  'LA': "Lao People's Democratic Republic",
#  'PF': 'French Polynesia',
#  'AN': 'Netherlands Antilles',
#  'CG': 'Congo',
#  'MM': 'Myanmar',
#  'BM': 'Bermuda',
#  'SV': 'El Salvador',
#  'TF': 'French Southern Territories',
#  'WS': 'Samoa',
#  'MD': 'Moldova',
#  'BB': 'Barbados',
#  'AQ': 'Antarctica',
#  'GI': 'Gibraltar',
#  'BN': 'Brunei Darussalam',
#  'HN': 'Honduras',
#  'GN': 'Guinea'}

# %%
countries = dict(sorted(countries.items()))
# countries

# %%
countries_df =pd.DataFrame(countries.values(),columns=['country_name'],index=countries.keys())
df_dict['production_countries'] = countries_df

# %%
def handle_production_countries(country):
    lst = filter_str(country)
    ids = [item['iso_3166_1'] for item in lst if 'iso_3166_1' in item]
    return ids

# handle_genre(df_dict['movies_metadata']['genres'][2])
production_countries  = df_dict['movies_metadata']['production_countries'].apply(lambda x: handle_production_countries(x))
df_dict['movies_metadata']['production_countries'] = production_countries
temp = df_dict['movies_metadata'][['production_countries','id']]
production_countries_relation = temp.explode('production_countries')
df_dict['movies_metadata'].drop(['production_countries'],axis=1,inplace=True)

# %%
df_dict['production_countries_relation'] = production_countries_relation

# %%
df_dict['movies_metadata']
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                             NaN  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                             NaN  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 45461  False                             NaN         0
# 45462  False                             NaN         0
# 45463  False                             NaN         0
# 45464  False                             NaN         0
# 45465  False                             NaN         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies release_date  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 3      [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...   1995-02-10
# ...                                                  ...          ...
# 45461                                                 []          NaN
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]   2011-11-17
# 45463  [{'name': 'American World Pictures', 'id': 6165}]   2003-08-01
# 45464               [{'name': 'Yermoliev', 'id': 88753}]   1917-10-21
# 45465                                                 []   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [45466 rows x 22 columns]

# %%
for item in df_dict['movies_metadata']['production_companies'][:10]:
    print(item)
# Out:
# [{'name': 'Pixar Animation Studios', 'id': 3}]
# [{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]
# [{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]
# [{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]
# [{'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Touchstone Pictures', 'id': 9195}]
# [{'name': 'Regency Enterprises', 'id': 508}, {'name': 'Forward Pass', 'id': 675}, {'name': 'Warner Bros.', 'id': 6194}]
# [{'name': 'Paramount Pictures', 'id': 4}, {'name': 'Scott Rudin Productions', 'id': 258}, {'name': 'Mirage Enterprises', 'id': 932}, {'name': 'Sandollar Productions', 'id': 5842}, {'name': 'Constellation Entertainment', 'id': 14941}, {'name': 'Worldwide', 'id': 55873}, {'name': 'Mont Blanc Entertainment GmbH', 'id': 58079}]
# [{'name': 'Walt Disney Pictures', 'id': 2}]
# [{'name': 'Universal Pictures', 'id': 33}, {'name': 'Imperial Entertainment', 'id': 21437}, {'name': 'Signature Entertainment', 'id': 23770}]
# [{'name': 'United Artists', 'id': 60}, {'name': 'Eon Productions', 'id': 7576}]

# %%
companies = dict()
for company in list(df_dict['movies_metadata']['production_companies']):
    lst = filter_str(company)
    for item in lst:
        if int(item['id']) not in companies:
            companies[int(item['id'])] = item['name']

# %%
companies = dict(sorted(companies.items()))
companies_df = pd.DataFrame(companies.values(),index=companies.keys(),columns=['company_name'])
companies_df
# Out:
#                                      company_name
# 1                                       Lucasfilm
# 2                            Walt Disney Pictures
# 3                         Pixar Animation Studios
# 4                              Paramount Pictures
# 5                               Columbia Pictures
# ...                                           ...
# 96028  Produzione Esecutiva Cinematografica (PEC)
# 96035                     Hawk's Nest Productions
# 96043                        Humble Journey Films
# 96053                              Ibérica Filmes
# 96067                    Country Road Productions
#
# [23692 rows x 1 columns]

# %%
def handle_production_companies(company):
    lst = filter_str(company)
    ids = [int(item['id']) for item in lst if 'id' in item]
    return ids


production_companies  = df_dict['movies_metadata']['production_companies'].apply(lambda x: handle_production_companies(x))
df_dict['movies_metadata']['production_companies'] = production_companies
temp = df_dict['movies_metadata'][['production_companies','id']]
production_companies_relation = temp.explode('production_companies')
df_dict['movies_metadata'].drop(['production_companies'],axis=1,inplace=True)
df_dict['production_companies_relation'] = production_companies_relation

# %%
df_dict['movies_metadata']
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                             NaN  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                             NaN  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 45461  False                             NaN         0
# 45462  False                             NaN         0
# 45463  False                             NaN         0
# 45464  False                             NaN         0
# 45465  False                             NaN         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path release_date      revenue  runtime  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373554033.0     81.0
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262797249.0    104.0
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22          0.0    101.0
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22   81452156.0    127.0
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10   76578911.0    106.0
# ...                                 ...          ...          ...      ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg          NaN          0.0     90.0
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg   2011-11-17          0.0    360.0
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg   2003-08-01          0.0     90.0
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg   1917-10-21          0.0     87.0
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg   2017-06-09          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [45466 rows x 21 columns]

# %%
for item in df_dict['movies_metadata']['spoken_languages'][:10]:
    print(item)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]
# [{'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso_639_1': 'es', 'name': 'Español'}]

# %%
spoken_languages = dict()
for lang in list(df_dict['movies_metadata']['spoken_languages']):
    lst = filter_str(lang)
    for item in lst:
        if item['iso_639_1'] not in spoken_languages:
            spoken_languages[item['iso_639_1']] = item['name']

spoken_languages
# Out:
# {'en': 'English',
#  'fr': 'Français',
#  'es': 'Español',
#  'de': 'Deutsch',
#  'ru': 'Pусский',
#  'la': 'Latin',
#  'nl': 'Nederlands',
#  'cn': '广州话 / 廣州話',
#  'zh': '普通话',
#  'hu': 'Magyar',
#  'sq': 'shqip',
#  'it': 'Italiano',
#  'ko': '한국어/조선말',
#  'fa': 'فارسی',
#  'da': 'Dansk',
#  'gd': '',
#  'ja': '日本語',
#  'ar': 'العربية',
#  'hr': 'Hrvatski',
#  'bs': 'Bosanski',
#  'mn': '',
#  'ro': 'Română',
#  'id': 'Bahasa indonesia',
#  'ms': 'Bahasa melayu',
#  'mk': '',
#  'sv': 'svenska',
#  'he': 'עִבְרִית',
#  'kw': '',
#  'cs': 'Český',
#  'nv': '',
#  'mi': '',
#  'tl': '',
#  'pl': 'Polski',
#  'ga': 'Gaeilge',
#  'no': 'Norsk',
#  'sk': 'Slovenčina',
#  'vi': 'Tiếng Việt',
#  'yi': '',
#  'pt': 'Português',
#  'hi': 'हिन्दी',
#  'ca': 'Català',
#  'is': 'Íslenska',
#  'af': 'Afrikaans',
#  'sr': 'Srpski',
#  'bn': 'বাংলা',
#  'wo': 'Wolof',
#  'cy': 'Cymraeg',
#  'th': 'ภาษาไทย',
#  'lv': 'Latviešu',
#  'sw': 'Kiswahili',
#  'bg': 'български език',
#  'el': 'ελληνικά',
#  'ne': '',
#  'tr': 'Türkçe',
#  'km': '',
#  'fi': 'suomi',
#  'eo': 'Esperanto',
#  'uk': 'Український',
#  'iu': '',
#  'ka': 'ქართული',
#  'sh': '',
#  'bo': '',
#  'nb': 'Bokmål',
#  'ty': '',
#  'xx': 'No Language',
#  'si': '',
#  'as': '',
#  'gn': '',
#  'eu': 'euskera',
#  'az': 'Azərbaycan',
#  'mt': 'Malti',
#  'ur': 'اردو',
#  'zu': 'isiZulu',
#  'lo': '',
#  'xh': '',
#  'bm': 'Bamanankan',
#  'cr': '',
#  'ps': 'پښتو',
#  'so': 'Somali',
#  'ku': '',
#  'hy': '',
#  'oc': '',
#  'pa': 'ਪੰਜਾਬੀ',
#  'to': '',
#  'ce': '',
#  'qu': '',
#  'be': 'беларуская мова',
#  'am': '',
#  'tg': '',
#  'tt': '',
#  'se': '',
#  'ml': '',
#  'ta': 'தமிழ்',
#  'co': '',
#  'gl': 'Galego',
#  'dz': '',
#  'rw': 'Kinyarwanda',
#  'ht': '',
#  'kk': 'қазақ',
#  'ln': '',
#  'my': '',
#  'et': 'Eesti',
#  'sa': '',
#  'lt': 'Lietuvi\x9akai',
#  'fy': '',
#  'tk': '',
#  'sl': 'Slovenščina',
#  'te': 'తెలుగు',
#  'ny': '',
#  'st': '',
#  'sc': '',
#  'gu': '',
#  'ff': 'Fulfulde',
#  'mr': '',
#  'ug': '',
#  'ay': '',
#  'ky': '??????',
#  'jv': '',
#  'br': '',
#  'sg': '',
#  'lb': '',
#  'ab': '',
#  'kn': '?????',
#  'uz': 'ozbek',
#  'sm': '',
#  'ki': '',
#  'tn': '',
#  'fo': '',
#  'sn': '',
#  'bi': '',
#  'ha': 'Hausa',
#  'ig': '',
#  'mh': ''}

# %%
no_value = []
for key,value in spoken_languages.items():
    if value == '':
        no_value.append(key)
    if '?' in value:
        spoken_languages[key] = ''
        no_value.append(key)

print(no_value)
# Out:
# ['gd', 'mn', 'mk', 'kw', 'nv', 'mi', 'tl', 'yi', 'ne', 'km', 'iu', 'sh', 'bo', 'ty', 'si', 'as', 'gn', 'lo', 'xh', 'cr', 'ku', 'hy', 'oc', 'to', 'ce', 'qu', 'am', 'tg', 'tt', 'se', 'ml', 'co', 'dz', 'ht', 'ln', 'my', 'sa', 'fy', 'tk', 'ny', 'st', 'sc', 'gu', 'mr', 'ug', 'ay', 'ky', 'jv', 'br', 'sg', 'lb', 'ab', 'kn', 'sm', 'ki', 'tn', 'fo', 'sn', 'bi', 'ig', 'mh']

# %%
spoken_df = pd.read_csv('/kaggle/input/spoken-lang/spoken_lang.csv',encoding='utf-8',usecols = ['ISO language name','639-1'])
spoken_df.head()
# Out:
#   ISO language name 639-1
# 0         Abkhazian    ab
# 1              Afar    aa
# 2         Afrikaans    af
# 3              Akan    ak
# 4          Albanian    sq

# %%
spoken_df.set_index('639-1',inplace=True)

# %%
# spoken_df.loc['cn']['ISO language name']

# %%
for key,_ in spoken_languages.items():
    if key.lower() in spoken_df.index:
        spoken_languages[key] = spoken_df.loc[key.lower()]['ISO language name']
spoken_languages
# Out:
# {'en': 'English',
#  'fr': 'French',
#  'es': 'Spanish, Castilian',
#  'de': 'German',
#  'ru': 'Russian',
#  'la': 'Latin',
#  'nl': 'Dutch,\xa0Flemish',
#  'cn': '广州话 / 廣州話',
#  'zh': 'Chinese',
#  'hu': 'Hungarian',
#  'sq': 'Albanian',
#  'it': 'Italian',
#  'ko': 'Korean',
#  'fa': 'Persian',
#  'da': 'Danish',
#  'gd': 'Gaelic, Scottish Gaelic',
#  'ja': 'Japanese',
#  'ar': 'Arabic',
#  'hr': 'Croatian',
#  'bs': 'Bosnian',
#  'mn': 'Mongolian',
#  'ro': 'Romanian,\xa0Moldavian, Moldovan',
#  'id': 'Indonesian',
#  'ms': 'Malay',
#  'mk': 'Macedonian',
#  'sv': 'Swedish',
#  'he': 'Hebrew',
#  'kw': 'Cornish',
#  'cs': 'Czech',
#  'nv': 'Navajo, Navaho',
#  'mi': 'Maori',
#  'tl': 'Tagalog',
#  'pl': 'Polish',
#  'ga': 'Irish',
#  'no': 'Norwegian',
#  'sk': 'Slovak',
#  'vi': 'Vietnamese',
#  'yi': 'Yiddish',
#  'pt': 'Portuguese',
#  'hi': 'Hindi',
#  'ca': 'Catalan, Valencian',
#  'is': 'Icelandic',
#  'af': 'Afrikaans',
#  'sr': 'Serbian',
#  'bn': 'Bengali',
#  'wo': 'Wolof',
#  'cy': 'Welsh',
#  'th': 'Thai',
#  'lv': 'Latvian',
#  'sw': 'Swahili',
#  'bg': 'Bulgarian',
#  'el': 'Greek, Modern (1453–)',
#  'ne': 'Nepali',
#  'tr': 'Turkish',
#  'km': 'Central Khmer',
#  'fi': 'Finnish',
#  'eo': 'Esperanto',
#  'uk': 'Ukrainian',
#  'iu': 'Inuktitut',
#  'ka': 'Georgian',
#  'sh': '',
#  'bo': 'Tibetan',
#  'nb': 'Norwegian Bokmål',
#  'ty': 'Tahitian',
#  'xx': 'No Language',
#  'si': 'Sinhala, Sinhalese',
#  'as': 'Assamese',
#  'gn': 'Guarani',
#  'eu': 'Basque',
#  'az': 'Azerbaijani',
#  'mt': 'Maltese',
#  'ur': 'Urdu',
#  'zu': 'Zulu',
#  'lo': 'Lao',
#  'xh': 'Xhosa',
#  'bm': 'Bambara',
#  'cr': 'Cree',
#  'ps': 'Pashto, Pushto',
#  'so': 'Somali',
#  'ku': 'Kurdish',
#  'hy': 'Armenian',
#  'oc': 'Occitan',
#  'pa': 'Punjabi, Panjabi',
#  'to': 'Tonga\xa0(Tonga Islands)',
#  'ce': 'Chechen',
#  'qu': 'Quechua',
#  'be': 'Belarusian',
#  'am': 'Amharic',
#  'tg': 'Tajik',
#  'tt': 'Tatar',
#  'se': 'Northern Sami',
#  'ml': 'Malayalam',
#  'ta': 'Tamil',
#  'co': 'Corsican',
#  'gl': 'Galician',
#  'dz': 'Dzongkha',
#  'rw': 'Kinyarwanda',
#  'ht': 'Haitian, Haitian Creole',
#  'kk': 'Kazakh',
#  'ln': 'Lingala',
#  'my': 'Burmese',
#  'et': 'Estonian',
#  'sa': 'Sanskrit',
#  'lt': 'Lithuanian',
#  'fy': 'Western Frisian',
#  'tk': 'Turkmen',
#  'sl': 'Slovenian',
#  'te': 'Telugu',
#  'ny': 'Chichewa, Chewa, Nyanja',
#  'st': 'Southern Sotho',
#  'sc': 'Sardinian',
#  'gu': 'Gujarati',
#  'ff': 'Fulah',
#  'mr': 'Marathi',
#  'ug': 'Uighur, Uyghur',
#  'ay': 'Aymara',
#  'ky': 'Kirghiz, Kyrgyz',
#  'jv': 'Javanese',
#  'br': 'Breton',
#  'sg': 'Sango',
#  'lb': 'Luxembourgish, Letzeburgesch',
#  'ab': 'Abkhazian',
#  'kn': 'Kannada',
#  'uz': 'Uzbek',
#  'sm': 'Samoan',
#  'ki': 'Kikuyu, Gikuyu',
#  'tn': 'Tswana',
#  'fo': 'Faroese',
#  'sn': 'Shona',
#  'bi': 'Bislama',
#  'ha': 'Hausa',
#  'ig': 'Igbo',
#  'mh': 'Marshallese'}

# %%
df_dict['movies_metadata']['spoken_languages'] = df_dict['movies_metadata']['spoken_languages'].fillna(0)

# %%
for item in df_dict['movies_metadata']['spoken_languages'][:10]:
    print(item)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]
# [{'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso_639_1': 'es', 'name': 'Español'}]

# %%
df_dict['movies_metadata']['spoken_languages'][:2].index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
st = "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]"
filter_str(st)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'es', 'name': 'Español'}]

# %%
df_dict['movies_metadata']['spoken_languages'].value_counts()[0]
# Out:
# 6

# %%
check = "[{'iso_639_1': 'bg', 'name': 'български език'}, {'iso_639_1': 'cs', 'name': 'Český'}, {'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'hu', 'name': 'Magyar'}, {'iso_639_1': 'ja', 'name': '日本語'}, {'iso_639_1': 'lt', 'name': 'Lietuvi\x9akai'}, {'iso_639_1': 'pl', 'name': 'Polski'}, {'iso_639_1': 'es', 'name': 'Español'}]"
(json.loads(str(check).strip().replace('\'', '"')))
# Out:
# [{'iso_639_1': 'bg', 'name': 'български език'},
#  {'iso_639_1': 'cs', 'name': 'Český'},
#  {'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'fr', 'name': 'Français'},
#  {'iso_639_1': 'hu', 'name': 'Magyar'},
#  {'iso_639_1': 'ja', 'name': '日本語'},
#  {'iso_639_1': 'lt', 'name': 'Lietuvi\x9akai'},
#  {'iso_639_1': 'pl', 'name': 'Polski'},
#  {'iso_639_1': 'es', 'name': 'Español'}]

# %%
import copy
import sys
def load_json(x):
    if x == 0:
        return None
    try:
        x = x.replace('\\','-') # without it the code will give expection due to \ in the string
        return json.loads(str(x).strip().replace('\'', '"'))
    except json.JSONDecodeError as e:
        print(f"Failed to decode: {x}")
        return None  # or return a default value

df_dict['movies_metadata']['spoken_languages'] = df_dict['movies_metadata']['spoken_languages'].apply(load_json)

# %%
df_dict['movies_metadata']['spoken_languages'].isna().sum()
# Out:
# 6

# %%
spoken_lang_relation = df_dict['movies_metadata'][['id','spoken_languages']].explode('spoken_languages').dropna()

# %%
spoken_lang_relation['spoken_languages'] = spoken_lang_relation['spoken_languages'].apply(lambda x: x['iso_639_1'])

# %%
spoken_lang_relation[spoken_lang_relation['spoken_languages'] == 'xx'].count()
# we have to remove this entries from our relation
# Out:
# id                  319
# spoken_languages    319
# dtype: int64

# %%
spoken_lang_relation = spoken_lang_relation[spoken_lang_relation['spoken_languages'] != 'xx']

# %%
spoken_lang_relation.reset_index(drop=True,inplace=True)

# %%
spoken_lang_relation
# Out:
#            id spoken_languages
# 0         862               en
# 1        8844               en
# 2        8844               fr
# 3       15602               en
# 4       31357               en
# ...       ...              ...
# 52976   30840               en
# 52977  439050               fa
# 52978  111109               tl
# 52979   67758               en
# 52980  461257               en
#
# [52981 rows x 2 columns]

# %%
df_dict['spoken_lang_relation'] = spoken_lang_relation

# %%
df_dict['movies_metadata'].drop(columns = ['spoken_languages'],axis= 1,inplace=True)

# %%
df_dict['movies_metadata'].head(10)
# Out:
#    adult           belongs_to_collection    budget  \
# 0  False            Toy Story Collection  30000000
# 1  False                             NaN  65000000
# 2  False       Grumpy Old Men Collection         0
# 3  False                             NaN  16000000
# 4  False  Father of the Bride Collection         0
# 5  False                             NaN  60000000
# 6  False                             NaN  58000000
# 7  False                             NaN         0
# 8  False                             NaN  35000000
# 9  False           James Bond Collection  58000000
#
#                                        homepage     id    imdb_id  \
# 0          http://toystory.disney.com/toy-story    862  tt0114709
# 1                                           NaN   8844  tt0113497
# 2                                           NaN  15602  tt0113228
# 3                                           NaN  31357  tt0114885
# 4                                           NaN  11862  tt0113041
# 5                                           NaN    949  tt0113277
# 6                                           NaN  11860  tt0114319
# 7                                           NaN  45325  tt0112302
# 8                                           NaN   9091  tt0114576
# 9  http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
# 5                en                         Heat
# 6                en                      Sabrina
# 7                en                 Tom and Huck
# 8                en                 Sudden Death
# 9                en                    GoldenEye
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
# 5  Obsessive master thief, Neil McCauley leads a ...  17.924927
# 6  An ugly duckling having undergone a remarkable...   6.677277
# 7  A mischievous young boy, Tom Sawyer, witnesses...   2.561161
# 8  International action superstar Jean Claude Van...    5.23158
# 9  James Bond must unmask the mysterious head of ...  14.686036
#
#                         poster_path release_date      revenue  runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373554033.0     81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262797249.0    104.0
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22          0.0    101.0
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22   81452156.0    127.0
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10   76578911.0    106.0
# 5  /zMyfPUelumio3tiDKPffaUpsQTD.jpg   1995-12-15  187436818.0    170.0
# 6  /jQh15y5YB7bWz1NtffNZmRw0s9D.jpg   1995-12-15          0.0    127.0
# 7  /sGO5Qa55p7wTu7FJcX4H4xIVKvS.jpg   1995-12-22          0.0     97.0
# 8  /eoWvKD60lT95Ss1MYNgVExpo5iU.jpg   1995-12-22   64350171.0    106.0
# 9  /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg   1995-11-16  352194034.0    130.0
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
# 5  Released                           A Los Angeles Crime Saga
# 6  Released  You are cordially invited to the most surprisi...
# 7  Released                             The Original Bad Boys.
# 8  Released                         Terror goes into overtime.
# 9  Released               No limits. No fears. No substitutes.
#
#                          title  video  vote_average  vote_count
# 0                    Toy Story  False           7.7      5415.0
# 1                      Jumanji  False           6.9      2413.0
# 2             Grumpier Old Men  False           6.5        92.0
# 3            Waiting to Exhale  False           6.1        34.0
# 4  Father of the Bride Part II  False           5.7       173.0
# 5                         Heat  False           7.7      1886.0
# 6                      Sabrina  False           6.2       141.0
# 7                 Tom and Huck  False           5.4        45.0
# 8                 Sudden Death  False           5.5       174.0
# 9                    GoldenEye  False           6.6      1194.0

# %%
languages_codes = pd.DataFrame({'code':spoken_languages.keys(),'name':spoken_languages.values()})

# %%
df_dict['genres'] = pd.DataFrame({'genre_id':df_dict['genre_dict'].keys(),'genre':df_dict['genre_dict'].values()})
df_dict['genres'].set_index('genre_id',inplace=True)

# %%
del df_dict['genre_dict']

# %% [markdown]
# # Save tables

# %%
for key,df in df_dict.items():
    df.to_parquet(key+'.parquet.gzip', compression='gzip')
